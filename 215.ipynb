# %% [markdown]
# `Machine Learning Start`
# <br>
# `Day1`

# %% [markdown]
# `Machine Learning Basics` <br>
#
# `def`: machine learning is a field of cs that uses statistical techniques to give computer systems the ability to 'learn' with data, without being explicitly programmed.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# `Difference between AI ML AND DL` <br>
# ai > ml > dl <br>
#
# deep learning is inspired by biology. <br>
# ![image.png](attachment:image.png) <br>
# deep learning performance imporved by given data more and more <br>

# %% [markdown]
# `Types of ML`
# <br>
# 1. Supervised - <br> ![image.png](attachment:image.png) <br>
#      - Regression - if output is numerical
#     - classification - if output is categorical
# 2. Unsupervised
#     - clustering
#     - dimensionality reduction
#     - Anamoly detection
#     - Association
# 3. Semi supervised
# 4. Reinforcement

# %% [markdown]
# 2. Unsupervised - only input is present no output -
#     - clustering -
#     - dimensionality reduction -
#     - Anamoly detection
#     - Association rule learning
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Semi supervised Learning

# %% [markdown]
# Semi-supervised learning is a type of machine learning that uses both labeled and unlabeled data for training. Typically, a small amount of labeled data is combined with a large amount of unlabeled data. This approach is useful when labeling data is expensive or time-consuming, but unlabeled data is abundant. Semi-supervised learning can improve learning accuracy compared to using only labeled data.

# %% [markdown]
# 4. Reinforcement Learning
# <br>
# ![image.png](attachment:image.png)

# %% [markdown]
# ` Run The ML algorithm method `

# %% [markdown]
# 1. Batch vs Online ML.
# <br>
#  - Batch learning training ->

# %% [markdown]
# `Challenges in ML` <br>
#  1. Data collection
#  2. Insufficient data/Labelled data
#  3. Non Representative Data
#  4. Poor quality data
#  5. Irrelevant features
#  6. Overfitting
#  7. Underfitting
#  8. Software integration
#  9. Offline learning / deployment
#  10. Cost Involved

# %% [markdown]
# Tobaco .com

# %% [markdown]
# `ML Development Life Cycle(MLDLC)` <br>
# **MLDC/MLDLC** <br>
# 1. Frame the problem
# 2. Gathering  Data
# 3. Data preprocessing
# 4. Exploratry Data analysis
# 5. Feature Engineering and Selection
# 6. Model Training, Evaluation and Selection
#     - Ensemble Learning
# 7. Model Deployment
# 8. Testing
#     - A/B testing
# 9. Optimize
#     - Model backup
#     - data backup
#     - retrain kab karna hai
#     - load balancing

# %% [markdown]
# **`Job Profiles In DataScience`**
# - Angle list website
#
#
#
#     - Data Engineer
#         - ![image.png](attachment:image.png)
#     - Data analyst
#         - ![image-2.png](attachment:image-2.png)
#     - Data scientist
#         - ![image-3.png](attachment:image-3.png)
#     - Machine Learning Engineer
#         - ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)
