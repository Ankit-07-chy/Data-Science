# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankit-07-chy/Data-Science/blob/main/230_Multicollinearity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - What is problem if feature columns are corelated?
#
#   e.g. lpa = f(iq,cpi)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Mulitcolinearity doesn't affect predictive model, affect in case of inference case.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Perfect Multicolinearity**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# if two input feature is perfect multicollinearity than there is no error terms in there relation.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# XTX)^-1 becomes singular matrix so we can't find B. -- applicable if perfect multicollinearity.

# %% [markdown]
# multicollinearity
#
#
# *   High Standart error
# *   Unstable Coefficients
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# for structural multicollinearity
#
# e.g. One hot encoding, polynomial regression,
#
# ### How to detect multicollinearity.
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# - If corr fucntion shows 0.8 or more than that it shows multicolinearity between then
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# for variance inflation factor there is code.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
