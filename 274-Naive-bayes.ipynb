# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# underflow-->
# - to protect from underflow use log probability.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Laplace Additive.(Bias Variance Tradeoff)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# for high value alpha --> high bias or variance(1:5)

# %% [markdown]
# ### tYPES   of naive bayes
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Gaussian Naive Bayes.
# - all feature are numerical then use this.
# - Why laplace additive is not applicable on gaussian naive bayes.
# - Homogenous data pe better result deta hai

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Categorical Naive bayes.
# - All features are categorical.
# - can add laplace additive smoothing. is appliyin only on coditional probability.
# -

# %% [markdown]
# 3. Multinomial Naive Bayes.
# - dataset having all features are discrete.(Textual Data)
# - same as binomial except in binomial we go for word came then 1 and not came then 0 but in this case we hace if came than how many times and if not then 0.

# %% [markdown]
# # 275

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - each feature will follow only 2 categorries.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
