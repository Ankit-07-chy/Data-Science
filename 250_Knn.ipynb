# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankit-07-chy/Data-Science/blob/main/250_Knn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
link = "https://raw.githubusercontent.com/arindal1/Breast-Cancer-Detection/master/data.csv"
df = pd.read_csv(link)

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop(columns=['id','Unnamed: 32'],inplace=True)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,1:],df.iloc[:,0],test_size=0.2,random_state=2)
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (455, 30) (114, 30) (455,) (114,)

# %%
from sklearn.preprocessing import StandardScaler
st = StandardScaler()
X_train = st.fit_transform(X_train)
X_test = st.transform(X_test)

# %%
X_train
# Out:
# array([[-0.01330339,  1.7757658 , -0.01491962, ..., -0.13236958,
#         -1.08014517, -0.03527943],
#        [-0.8448276 , -0.6284278 , -0.87702746, ..., -1.11552632,
#         -0.85773964, -0.72098905],
#        [ 1.44755936,  0.71180168,  1.47428816, ...,  0.87583964,
#          0.4967602 ,  0.46321706],
#        ...,
#        [-0.46608541, -1.49375484, -0.53234924, ..., -1.32388956,
#         -1.02997851, -0.75145272],
#        [-0.50025764, -1.62161319, -0.527814  , ..., -0.0987626 ,
#          0.35796577, -0.43906159],
#        [ 0.96060511,  1.21181916,  1.00427242, ...,  0.8956983 ,
#         -1.23064515,  0.50697397]])

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (455, 30) (114, 30) (455,) (114,)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn.metrics import accuracy_score
y_pred = knn.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9912280701754386

# %%
#selecting K with high accuracy score

scores = []
for i in range(1,16):
  knn = KNeighborsClassifier(n_neighbors=i)
  knn.fit(X_train,y_train)
  y_pred = knn.predict(X_test)
  scores.append(accuracy_score(y_test,y_pred))

# %%
scores
# Out:
# [0.956140350877193,
#  0.9736842105263158,
#  0.9912280701754386,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9649122807017544,
#  0.9649122807017544]

# %%
plt.plot(range(1,16),scores)
plt.xlabel("K")
plt.ylabel("Accuracy")
plt.show()

# %%
# decision surface
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.svm import SVC

# Load Iris dataset (or your own 2D data)
iris = datasets.load_iris()
X = iris.data[:, [0, 2]]   # two features
y = iris.target  # class labels (0,1,2)

# Train a classifier
clf = SVC(C=1.0, kernel='linear', gamma='auto')
clf.fit(X, y)

# Plot decision regions
plt.figure(figsize=(8,6))
plot_decision_regions(X, y, clf=clf, legend=2)

plt.xlabel('Feature 0 (e.g. sepal length)')
plt.ylabel('Feature 2 (e.g. petal length)')
plt.title('SVM Decision Surface on Iris')
plt.show()

# %%
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,1:],df.iloc[:,0],test_size=0.2,random_state=2)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Plot decision regions
plt.figure(figsize=(8,6))
plot_decision_regions(df.iloc[:,1:3].values, df.iloc[:,0].values, clf=knn, legend=2)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-30-3255054725.py in <cell line: 0>()
#       1 # Plot decision regions
#       2 plt.figure(figsize=(8,6))
# ----> 3 plot_decision_regions(df.iloc[:,1:3].values, df.iloc[:,0].values, clf=knn, legend=2)
#       4
#       5
#
# /usr/local/lib/python3.11/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     159     """
#     160
# --> 161     check_Xy(X, y, y_int=True)  # Validate X and y arrays
#     162     dim = X.shape[1]
#     163
#
# /usr/local/lib/python3.11/dist-packages/mlxtend/utils/checking.py in check_Xy(X, y, y_int)
#      18
# ...

# %%
X = df.iloc[:, 1:3].values    # example: select two features (cols 1 and 2)
y = df.iloc[:, 0].values      # target column (col 0)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X, y)

plt.figure(figsize=(8, 6))
plot_decision_regions(X, y, clf=knn, legend=2)

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('KNN Decision Surface')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-31-4101019368.py in <cell line: 0>()
#       6
#       7 plt.figure(figsize=(8, 6))
# ----> 8 plot_decision_regions(X, y, clf=knn, legend=2)
#       9
#      10 plt.xlabel('Feature 1')
#
# /usr/local/lib/python3.11/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     159     """
#     160
# --> 161     check_Xy(X, y, y_int=True)  # Validate X and y arrays
#     162     dim = X.shape[1]
#     163
#
# /usr/local/lib/python3.11/dist-packages/mlxtend/utils/checking.py in check_Xy(X, y, y_int)
#      18
#      19     if "int" not in str(y.dtype):
# ...
